# %% [markdown]
# # GROP 3:DOMAIN ENVIRONMENTAL POLLUTION
# #DATASET AIR QUALITY INDEX FROM KAGGLE
# #AQI IN 5 CITY TAKEN

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# imported all the libraries

# %% [markdown]
# # data set reading

# %%
aqf=pd.read_csv("dataset_new.csv")

# %%
aqf.head()
# Out:
#    Unnamed: 0       City        Date  PM2.5  PM10     NO    NO2    NOx    NH3  \
# 0        4294  Bengaluru  2015-01-01    NaN   NaN   3.26  17.33  10.88  20.36
# 1        4295  Bengaluru  2015-01-02    NaN   NaN   6.05  19.73  14.14  23.74
# 2        4296  Bengaluru  2015-01-03    NaN   NaN  11.91  19.88  20.72   4.32
# 3        4297  Bengaluru  2015-01-04    NaN   NaN   7.45  21.61  16.88   0.87
# 4        4298  Bengaluru  2015-01-05    NaN   NaN   9.52  22.17  21.76  31.38
#
#       CO    SO2     O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0   0.33   3.54  10.73     0.56     4.64     NaN  NaN        NaN
# 1   1.35   3.97  22.77     0.65     5.31     NaN  NaN        NaN
# 2  17.40  13.61  12.03     0.53    19.25     NaN  NaN        NaN
# 3   5.05   6.52  17.70     0.55     7.47     NaN  NaN        NaN
# 4   1.83   4.71  12.72     0.40     4.36     NaN  NaN        NaN

# %%
aqf.isna().sum()
#checking null values
# Out:
# Unnamed: 0       0
# City             0
# Date             0
# PM2.5          317
# PM10          2116
# NO             132
# NO2            139
# NOx             64
# NH3            905
# CO              59
# SO2             80
# O3             389
# Benzene       1670
# Toluene       1465
# Xylene        5520
# AQI            335
# AQI_Bucket     335
# dtype: int64

# %%
aqf.shape
# Out:
# (5678, 17)

# %% [markdown]
# droppinf cloumns  have 90% null values

# %%
aq_df=aqf.drop(['Benzene','Toluene','Xylene','AQI_Bucket','Unnamed: 0'],axis=1)

# %%
aq_df
# Out:
#                     City        Date  PM2.5   PM10     NO    NO2    NOx  \
# 0              Bengaluru  2015-01-01    NaN    NaN   3.26  17.33  10.88
# 1              Bengaluru  2015-01-02    NaN    NaN   6.05  19.73  14.14
# 2              Bengaluru  2015-01-03    NaN    NaN  11.91  19.88  20.72
# 3              Bengaluru  2015-01-04    NaN    NaN   7.45  21.61  16.88
# 4              Bengaluru  2015-01-05    NaN    NaN   9.52  22.17  21.76
# ...                  ...         ...    ...    ...    ...    ...    ...
# 5673  Thiruvananthapuram  2020-06-27  18.06  36.04   8.19   9.50  12.46
# 5674  Thiruvananthapuram  2020-06-28  22.51  43.97   7.00   7.38   9.57
# 5675  Thiruvananthapuram  2020-06-29  23.17  46.71   8.87  10.75  12.88
# 5676  Thiruvananthapuram  2020-06-30  20.66  41.53   8.65   9.93  12.41
# 5677  Thiruvananthapuram  2020-07-01   2.00  35.00   1.68   2.30   2.58
#
#         NH3     CO    SO2     O3   AQI
# 0     20.36   0.33   3.54  10.73   NaN
# ...

# %% [markdown]
# sum of null in cloumns

# %%
aq_df.isna().sum()
# Out:
# City        0
# Date        0
# PM2.5     317
# PM10     2116
# NO        132
# NO2       139
# NOx        64
# NH3       905
# CO         59
# SO2        80
# O3        389
# AQI       335
# dtype: int64

# %%
aq_df.describe(include='all')
# Out:
#              City        Date        PM2.5         PM10           NO  \
# count        5678        5678  5361.000000  3562.000000  5546.000000
# unique          5        2009          NaN          NaN          NaN
# top     Bengaluru  2020-05-29          NaN          NaN          NaN
# freq         2009           5          NaN          NaN          NaN
# mean          NaN         NaN    38.630358    65.988770     8.441973
# std           NaN         NaN    24.198817    37.273798     9.216053
# min           NaN         NaN     1.720000     0.210000     0.060000
# 25%           NaN         NaN    21.950000    39.415000     3.750000
# 50%           NaN         NaN    33.990000    58.245000     6.850000
# 75%           NaN         NaN    49.450000    84.972500    10.070000
# max           NaN         NaN   313.590000   351.510000   152.120000
#
#                 NO2          NOx          NH3           CO          SO2  \
# ...

# %%
aq_df.dtypes
# Out:
# City      object
# Date      object
# PM2.5    float64
# PM10     float64
# NO       float64
# NO2      float64
# NOx      float64
# NH3      float64
# CO       float64
# SO2      float64
# O3       float64
# AQI      float64
# dtype: object

# %%
fregraph=aq_df.select_dtypes(include=['float'])
fregraph.hist(figsize=(20,15))
plt.show()

# %%
for i in['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','AQI']:
   # for k in['orange','blue','green','brown','yellow','pink','red','cyan','grey','INDIGO']:
        sns.distplot(aq_df[i],kde=True,bins=20,color='blue')
        plt.show()

# %%
#AQI
fig, ax = plt.subplots(figsize=(10,5))        
sns.distplot(aq_df.AQI, kde=True);

# %% [markdown]
# Note: from the distribution plots it is clear that all the features are right skewed so we can use median/mode to fill missing values.

# %%
aq_df['City'].value_counts()
# Out:
# Bengaluru             2009
# Chennai               2009
# Thiruvananthapuram    1112
# Coimbatore             386
# Ernakulam              162
# Name: City, dtype: int64

# %%
#fig, axes = plt.subplots(1, 3, figsize=(10, 5))
#print(fig)
fig,axes = plt.subplots(3,3, figsize=(40,50))

#plotting PM2_5 vs City
sns.stripplot(ax=axes[0,0],data=aq_df,x=aq_df['City'],y=aq_df["PM2.5"]).set_title("Plot of PM2_5 vs City")
sns.boxplot(ax=axes[0,0],data=aq_df,x=aq_df['City'],y=aq_df["PM2.5"]).set_title("Plot of PM2_5 vs City")

#plotting PM10 vs City
sns.stripplot(ax=axes[0,1],data=aq_df,x=aq_df['City'],y=aq_df["PM10"]).set_title("Plot of PM10 vs City")
sns.boxplot(ax=axes[0,1],data=aq_df,x=aq_df['City'],y=aq_df["PM10"]).set_title("Plot of PM10 vs City")

#plotting NO vs City
sns.stripplot(ax=axes[0,2],data=aq_df,x=aq_df['City'],y=aq_df["NO"]).set_title("Plot of NO vs City")
sns.boxplot(ax=axes[0,2],data=aq_df,x=aq_df['City'],y=aq_df["NO"]).set_title("Plot of NO vs City")

#plotting NO2 vs City
sns.stripplot(ax=axes[1,0],data=aq_df,x=aq_df['City'],y=aq_df["NO2"]).set_title("Plot of NO2 vs City")
sns.boxplot(ax=axes[1,0],data=aq_df,x=aq_df['City'],y=aq_df["NO2"]).set_title("Plot of NO2 vs City")

#plotting NOx vs City
sns.stripplot(ax=axes[1,1],data=aq_df,x=aq_df['City'],y=aq_df["NOx"]).set_title("Plot of NOx vs City")
sns.boxplot(ax=axes[1,1],data=aq_df,x=aq_df['City'],y=aq_df["NOx"]).set_title("Plot of NOx vs City")

#plotting NH3 vs City
sns.stripplot(ax=axes[1,2],data=aq_df,x=aq_df['City'],y=aq_df["NH3"]).set_title("Plot of NH3 vs City")
sns.boxplot(ax=axes[1,2],data=aq_df,x=aq_df['City'],y=aq_df["NH3"]).set_title("Plot of NH3 vs City")

#plotting CO vs City
sns.stripplot(ax=axes[2,0],data=aq_df,x=aq_df['City'],y=aq_df["CO"]).set_title("Plot of CO vs City")
sns.boxplot(ax=axes[2,0],data=aq_df,x=aq_df['City'],y=aq_df["CO"]).set_title("Plot of CO vs City")

#plotting SO2 vs City
sns.stripplot(ax=axes[2,1],data=aq_df,x=aq_df['City'],y=aq_df["SO2"]).set_title("Plot of SO2 vs City")
sns.boxplot(ax=axes[2,1],data=aq_df,x=aq_df['City'],y=aq_df["SO2"]).set_title("Plot of SO2 vs City")

#plotting O3 vs City
sns.stripplot(ax=axes[2,2],data=aq_df,x=aq_df['City'],y=aq_df["O3"]).set_title("Plot of O3 vs City")
sns.boxplot(ax=axes[2,2],data=aq_df,x=aq_df['City'],y=aq_df["O3"]).set_title("Plot of O3 vs City")


fig.suptitle("Strip plots of features which are going to be checked for outliers")
fig.tight_layout()

# %% [markdown]
# insigts:city vs contents
#     presence of 03 greater in all cities
#     outliers exixts in almost all columns

# %%
aq_df[aq_df["AQI"].isna()]["City"].value_counts()
# Out:
# Chennai               125
# Bengaluru              99
# Thiruvananthapuram     60
# Coimbatore             42
# Ernakulam               9
# Name: City, dtype: int64

# %%
#for loop for filling null values from a bove graph we found that all graph are right skewed so we can us median
for i in['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','AQI']:
    aq_df[i]=aq_df[i].fillna(aq_df[i].median())

# %%
aq_df.isna().sum()
# Out:
# City     0
# Date     0
# PM2.5    0
# PM10     0
# NO       0
# NO2      0
# NOx      0
# NH3      0
# CO       0
# SO2      0
# O3       0
# AQI      0
# dtype: int64

# %% [markdown]
# now no null in columns

# %%
aq_df.shape
# Out:
# (5678, 12)

# %% [markdown]
# # handling outliers

# %%
import numpy as np

# %%
Q1=np.percentile(aq_df['PM2.5'],25,interpolation='midpoint')
Q2=np.percentile(aq_df['PM2.5'],50,interpolation='midpoint')
Q3=np.percentile(aq_df['PM2.5'],75,interpolation='midpoint')

# %%
IQR=Q3-Q1

# %%
low_lim=Q1-1.5*IQR
up_limit=Q3+1.5*IQR

# %%
print(up_limit)
print(low_lim)
# Out:
# 86.32249999999999
# -15.6175

# %%
outlier=[]
for x in aq_df['PM2.5']:
    if(x>up_limit)or(x<low_lim):
        outlier.append(x)

# %%
aq_df.shape
# Out:
# (5678, 12)

# %%
outlier
# Out:
# [87.02,
#  119.16,
#  91.95,
#  90.07,
#  134.69,
#  110.05,
#  98.29,
#  239.54,
#  121.43,
#  152.94,
#  115.98,
#  218.17,
#  101.09,
#  100.39,
#  97.17,
#  102.01,
#  91.6,
#  86.62,
#  204.25,
#  120.56,
#  313.59,
#  97.97,
#  158.67,
#  114.92,
#  121.63,
#  122.41,
#  197.41,
#  93.7,
#  103.18,
#  90.59,
#  161.35,
#  107.9,
#  159.52,
#  187.49,
#  113.31,
#  108.3,
#  88.98,
#  86.94,
#  98.84,
#  94.17,
#  92.21,
#  173.51,
#  149.04,
#  205.65,
#  140.21,
#  266.29,
#  88.65,
#  144.46,
#  103.75,
#  106.27,
#  187.51,
#  87.48,
#  90.72,
#  100.77,
#  120.24,
#  91.69,
#  87.7,
#  97.96,
#  97.74,
#  90.87,
#  125.51,
#  113.78,
#  119.68,
#  105.59,
#  100.5,
#  102.97,
#  127.46,
#  129.49,
#  100.13,
#  108.88,
#  111.48,
#  86.4,
#  122.16,
#  90.73,
#  138.07,
#  107.65,
#  112.72,
#  127.03,
#  92.83,
#  98.75,
#  90.02,
#  87.07,
#  100.61,
#  98.47,
#  123.36,
#  89.6,
#  109.5,
#  96.65,
#  196.81,
#  87.04,
#  92.64,
#  98.0,
#  132.38,
#  114.08,
#  88.08,
# ...

# %%
len(outlier)
# Out:
# 177

# %%
ind1=aq_df['PM2.5']>up_limit
p2=aq_df.loc[ind1].index

# %%
p2
# Out:
# Int64Index([ 393,  395,  406,  417,  418,  419,  443,  444,  445,  507,
#             ...
#             3781, 3782, 3783, 3848, 3998, 4006, 4728, 4785, 5109, 5535],
#            dtype='int64', length=177)

# %%
aq_df.drop(p2,inplace=True,axis=0)

# %%
aq_df.shape
# Out:
# (5501, 12)

# %%
ind1=aq_df['PM2.5']<low_lim
p2m=aq_df.loc[ind1].index

# %%
p2m
# Out:
# Int64Index([], dtype='int64')

# %%
aq_df.shape
# Out:
# (5501, 12)

# %%
Q1=np.percentile(aq_df['PM10'],25,interpolation='midpoint')
Q2=np.percentile(aq_df['PM10'],50,interpolation='midpoint')
Q3=np.percentile(aq_df['PM10'],75,interpolation='midpoint')

# %%
IQR=Q3-Q1
low_lim=Q1-1.5*IQR
up_limit=Q3+1.5*IQR
print(up_limit)
print(low_lim)
outlier=[]
for x in aq_df['PM10']:
    if(x>up_limit)or(x<low_lim):
        outlier.append(x)
# Out:
# 92.78
# 23.819999999999997

# %%
outlier
# Out:
# [153.3,
#  156.84,
#  16.77,
#  8.22,
#  16.42,
#  15.69,
#  112.78,
#  114.34,
#  102.15,
#  100.76,
#  95.08,
#  93.92,
#  99.34,
#  104.62,
#  105.12,
#  160.0,
#  172.02,
#  160.87,
#  235.32,
#  149.82,
#  133.08,
#  113.92,
#  122.54,
#  150.78,
#  133.63,
#  121.42,
#  108.47,
#  130.22,
#  158.01,
#  159.14,
#  193.59,
#  152.36,
#  121.86,
#  169.11,
#  351.51,
#  154.26,
#  223.57,
#  256.75,
#  164.48,
#  146.45,
#  113.87,
#  100.3,
#  108.68,
#  145.32,
#  138.17,
#  146.23,
#  116.89,
#  107.54,
#  100.6,
#  102.39,
#  98.29,
#  115.9,
#  144.04,
#  154.64,
#  134.78,
#  148.57,
#  137.04,
#  132.73,
#  120.86,
#  120.32,
#  122.4,
#  150.19,
#  161.1,
#  173.24,
#  163.88,
#  144.67,
#  148.74,
#  144.33,
#  144.2,
#  151.36,
#  194.0,
#  190.04,
#  186.28,
#  180.42,
#  183.03,
#  165.97,
#  175.45,
#  157.8,
#  162.1,
#  142.17,
#  156.52,
#  150.05,
#  159.41,
#  157.92,
#  165.25,
#  215.52,
#  254.77,
#  208.97,
#  318.02,
#  152.78,
#  144.68,
#  159.23,
# ...

# %%
len(outlier)
# Out:
# 882

# %%
ind1=aq_df['PM10']>up_limit
pi=aq_df.loc[ind1].index

# %%
pi
# Out:
# Int64Index([ 316,  317,  330,  331,  337,  348,  365,  366,  367,  368,
#             ...
#             5152, 5153, 5195, 5196, 5201, 5252, 5253, 5254, 5255, 5554],
#            dtype='int64', length=675)

# %%
ind1=aq_df['PM10']<low_lim
pi1=aq_df.loc[ind1].index

# %%
pi1
# Out:
# Int64Index([ 319,  320,  321,  325,  514,  518,  522,  523,  524,  525,
#             ...
#             5425, 5432, 5433, 5464, 5603, 5604, 5646, 5647, 5648, 5652],
#            dtype='int64', length=207)

# %%
aq_df.drop(pi,inplace=True,axis=0)

# %%
aq_df.shape
# Out:
# (4826, 12)

# %%
Q1=np.percentile(aq_df['NO'],25,interpolation='midpoint')
Q2=np.percentile(aq_df['NO'],50,interpolation='midpoint')
Q3=np.percentile(aq_df['NO'],75,interpolation='midpoint')
IQR=Q3-Q1
low_lim=Q1-1.5*IQR
up_limit=Q3+1.5*IQR
print(up_limit)
print(low_lim)
outlier=[]
for x in aq_df['NO']:
    if(x>up_limit)or(x<low_lim):
        outlier.append(x)
# Out:
# 18.8425
# -5.737499999999999

# %%
outlier
# Out:
# [22.6,
#  86.9,
#  62.22,
#  36.24,
#  35.23,
#  21.66,
#  25.04,
#  23.41,
#  24.29,
#  20.49,
#  22.95,
#  20.35,
#  20.86,
#  22.68,
#  20.76,
#  22.45,
#  20.87,
#  29.68,
#  42.37,
#  46.57,
#  57.18,
#  38.5,
#  23.76,
#  44.68,
#  24.11,
#  20.32,
#  20.84,
#  26.89,
#  69.97,
#  22.08,
#  30.59,
#  19.25,
#  39.37,
#  49.24,
#  20.75,
#  38.94,
#  42.05,
#  28.39,
#  32.78,
#  24.59,
#  28.13,
#  23.02,
#  20.04,
#  19.76,
#  19.67,
#  24.08,
#  21.68,
#  23.38,
#  23.61,
#  20.8,
#  19.12,
#  19.51,
#  22.31,
#  22.92,
#  24.38,
#  21.34,
#  25.62,
#  20.83,
#  22.69,
#  24.42,
#  24.51,
#  21.82,
#  19.25,
#  20.52,
#  20.06,
#  26.3,
#  23.91,
#  28.53,
#  21.53,
#  19.45,
#  26.1,
#  31.34,
#  30.58,
#  43.92,
#  26.74,
#  39.24,
#  55.04,
#  23.78,
#  48.95,
#  29.88,
#  24.48,
#  42.76,
#  21.82,
#  43.8,
#  45.63,
#  34.64,
#  34.39,
#  30.07,
#  44.65,
#  21.66,
#  44.76,
#  21.43,
#  30.73,
#  35.48,
#  46.92,
#  24.83,
#  31.78,
#  37.45,
#  23.17,
#  59.44,
# ...

# %%
len(outlier)
# Out:
# 215

# %%
ind1=aq_df['NO']>up_limit
ni=aq_df.loc[ind1].index

# %%
ni
# Out:
# Int64Index([   6,   28,   29,   30,   76,  270,  343,  344,  351,  352,
#             ...
#             4496, 5487, 5490, 5620, 5621, 5622, 5623, 5624, 5625, 5626],
#            dtype='int64', length=215)

# %%
aq_df.drop(ni,inplace=True,axis=0)

# %%
aq_df.shape
# Out:
# (4611, 12)

# %%
ind1=aq_df['NO']<low_lim
nim=aq_df.loc[ind1].index
nim
# Out:
# Int64Index([], dtype='int64')

# %%
aq_df.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'AQI'],
#       dtype='object')

# %%
Q1=np.percentile(aq_df['NO2'],25,interpolation='midpoint')
Q2=np.percentile(aq_df['NO2'],50,interpolation='midpoint')
Q3=np.percentile(aq_df['NO2'],75,interpolation='midpoint')
IQR=Q3-Q1
low_lim=Q1-1.5*IQR
up_limit=Q3+1.5*IQR
print(up_limit)
print(low_lim)
outlier=[]
for x in aq_df['NO2']:
    if(x>up_limit)or(x<low_lim):
        outlier.append(x)
# Out:
# 40.415
# -8.105

# %%
outlier
# Out:
# [41.16,
#  58.6,
#  71.63,
#  51.64,
#  44.41,
#  57.62,
#  42.88,
#  40.72,
#  43.97,
#  53.53,
#  51.22,
#  42.79,
#  42.69,
#  41.42,
#  43.48,
#  40.9,
#  59.8,
#  46.38,
#  63.82,
#  40.89,
#  40.55,
#  43.93,
#  58.2,
#  45.34,
#  57.48,
#  44.34,
#  49.0,
#  64.96,
#  70.5,
#  43.09,
#  51.16,
#  40.71,
#  41.35,
#  41.89,
#  41.08,
#  43.35,
#  42.47,
#  42.75,
#  46.1,
#  50.65,
#  48.12,
#  47.51,
#  50.06,
#  42.05,
#  42.47,
#  47.64,
#  42.57,
#  48.64,
#  63.33,
#  50.27,
#  115.11,
#  142.35,
#  61.7,
#  44.73,
#  44.56,
#  48.73,
#  42.6,
#  41.94,
#  42.23,
#  41.7,
#  50.19,
#  46.14,
#  46.38,
#  43.41,
#  45.27,
#  45.34,
#  53.65,
#  47.07,
#  41.15,
#  42.11,
#  46.93,
#  41.03,
#  46.1,
#  41.23,
#  40.82,
#  40.93,
#  61.67,
#  43.86,
#  41.45,
#  43.21,
#  57.52,
#  54.12,
#  58.36,
#  52.78,
#  56.59,
#  76.87,
#  67.22,
#  60.29,
#  61.69,
#  67.32,
#  58.28,
#  58.35,
#  45.88,
#  46.36,
#  41.31,
#  43.14,
#  62.1,
#  83.07,
#  66.14,
#  55.45,
#  46.19,
# ...

# %%
len(outlier)
# Out:
# 181

# %%
ind1=aq_df['NO2']>up_limit
noi=aq_df.loc[ind1].index
noi
aq_df.drop(noi,inplace=True,axis=0)

# %%
aq_df.shape
# Out:
# (4430, 12)

# %%
ind1=aq_df['NO2']>up_limit
noim=aq_df.loc[ind1].index
noim
# Out:
# Int64Index([], dtype='int64')

# %%
Q1=np.percentile(aq_df['NOx'],25,interpolation='midpoint')
Q2=np.percentile(aq_df['NOx'],50,interpolation='midpoint')
Q3=np.percentile(aq_df['NOx'],75,interpolation='midpoint')
IQR=Q3-Q1
low_lim=Q1-1.5*IQR
up_limit=Q3+1.5*IQR
print(up_limit)
print(low_lim)
outlier=[]
for x in aq_df['NOx']:
    if(x>up_limit)or(x<low_lim):
        outlier.append(x)
# Out:
# 39.082499999999996
# -10.657499999999995

# %%
outlier
# Out:
# [65.31,
#  47.53,
#  50.52,
#  62.33,
#  41.9,
#  43.24,
#  39.18,
#  41.42,
#  41.59,
#  42.15,
#  39.47,
#  41.69,
#  39.6,
#  41.65,
#  39.15,
#  39.72,
#  41.65,
#  48.69,
#  39.71,
#  39.94,
#  40.58,
#  43.73,
#  40.6,
#  39.85,
#  42.27,
#  40.96,
#  44.76,
#  39.69,
#  41.99,
#  41.05,
#  43.46,
#  39.56,
#  41.45,
#  46.29,
#  39.31,
#  41.64,
#  39.33,
#  39.68,
#  41.71,
#  41.84,
#  40.44,
#  39.14,
#  39.43,
#  40.48,
#  39.78,
#  40.19,
#  39.77]

# %%
len(outlier)
# Out:
# 47

# %%
ind1=aq_df['NOx']>up_limit
noxi=aq_df.loc[ind1].index
noxi
# Out:
# Int64Index([ 624, 1035, 1036, 1037, 1075, 1196, 1197, 1198, 1206, 1350, 1351,
#             1353, 1361, 1377, 1409, 1444, 1462, 1726, 1744, 1785, 1791, 1842,
#             1849, 3684, 3767, 3772, 4144, 4161, 4164, 4170, 4171, 4173, 4178,
#             4179, 4181, 4182, 4185, 4187, 4189, 4194, 4214, 4260, 4285, 4291,
#             4293, 4342, 4348],
#            dtype='int64')

# %%
aq_df.drop(noxi,inplace=True,axis=0)

# %%
aq_df.shape
# Out:
# (4383, 12)

# %%
Q1=np.percentile(aq_df['NH3'],25,interpolation='midpoint')
Q2=np.percentile(aq_df['NH3'],50,interpolation='midpoint')
Q3=np.percentile(aq_df['NH3'],75,interpolation='midpoint')
IQR=Q3-Q1
low_lim=Q1-1.5*IQR
up_limit=Q3+1.5*IQR
print(up_limit)
print(low_lim)
outlier=[]
for x in aq_df['NH3']:
    if(x>up_limit)or(x<low_lim):
        outlier.append(x)
# Out:
# 66.66749999999999
# -28.232499999999998

# %%
outlier
# Out:
# [75.14,
#  104.81,
#  84.26,
#  90.65,
#  76.99,
#  81.78,
#  68.44,
#  82.48,
#  116.59,
#  113.29,
#  85.61,
#  98.16,
#  103.03,
#  110.13,
#  105.68,
#  114.96,
#  74.0,
#  74.89,
#  73.15,
#  71.95,
#  73.0,
#  77.18,
#  67.45,
#  67.74,
#  67.74,
#  142.84,
#  129.91,
#  210.06,
#  186.57,
#  197.29,
#  176.1,
#  210.23,
#  124.02,
#  128.37,
#  148.89,
#  145.71,
#  135.17,
#  142.9,
#  81.89,
#  130.64,
#  68.35,
#  131.43,
#  141.84,
#  142.26,
#  172.14,
#  119.06,
#  113.53,
#  83.48,
#  139.64,
#  180.77,
#  302.08,
#  147.67,
#  86.29,
#  122.67,
#  104.23,
#  80.86,
#  69.02,
#  102.37,
#  123.26,
#  209.8,
#  223.87,
#  352.89,
#  201.85,
#  236.87,
#  256.27,
#  275.78,
#  225.01,
#  309.04,
#  196.84,
#  123.82,
#  206.54,
#  283.67,
#  132.94,
#  96.9,
#  98.22,
#  160.08,
#  181.86,
#  285.95,
#  296.29,
#  173.32,
#  187.56,
#  121.14,
#  295.74,
#  227.92,
#  177.66,
#  152.68,
#  186.53,
#  149.22,
#  128.27,
#  188.8,
#  174.22,
#  169.19,
#  102.74,
# ...

# %%
len(outlier)
# Out:
# 446

# %%
ind1=aq_df['NH3']>up_limit
nhi=aq_df.loc[ind1].index
nhi
# Out:
# Int64Index([ 517,  618, 1088, 1136, 2044, 2045, 2054, 2055, 2056, 2057,
#             ...
#             3834, 3835, 3885, 3887, 3888, 3889, 3890, 3902, 3903, 3904],
#            dtype='int64', length=446)

# %%
aq_df.drop(nhi,inplace=True,axis=0)

# %%
aq_df.shape
# Out:
# (3937, 12)

# %%
Q1=np.percentile(aq_df['CO'],25,interpolation='midpoint')
Q2=np.percentile(aq_df['CO'],50,interpolation='midpoint')
Q3=np.percentile(aq_df['CO'],75,interpolation='midpoint')
IQR=Q3-Q1
low_lim=Q1-1.5*IQR
up_limit=Q3+1.5*IQR
print(up_limit)
print(low_lim)
outlier=[]
for x in aq_df['CO']:
    if(x>up_limit)or(x<low_lim):
        outlier.append(x)
# Out:
# 1.8949999999999998
# -0.06499999999999984

# %%
outlier
# Out:
# [17.4,
#  5.05,
#  2.3,
#  2.59,
#  3.29,
#  16.41,
#  15.98,
#  9.04,
#  8.09,
#  4.05,
#  18.3,
#  3.32,
#  5.04,
#  2.42,
#  3.39,
#  5.39,
#  4.87,
#  2.35,
#  3.23,
#  2.18,
#  6.95,
#  8.98,
#  6.28,
#  13.56,
#  4.78,
#  3.56,
#  14.67,
#  3.39,
#  29.33,
#  23.53,
#  25.7,
#  16.01,
#  25.5,
#  1.9,
#  13.01,
#  18.28,
#  29.93,
#  25.25,
#  17.79,
#  15.98,
#  4.55,
#  3.89,
#  11.29,
#  9.95,
#  10.05,
#  2.85,
#  8.07,
#  8.53,
#  9.6,
#  4.06,
#  5.34,
#  9.58,
#  2.3,
#  6.84,
#  5.82,
#  5.19,
#  2.65,
#  2.23,
#  5.45,
#  12.93,
#  3.84,
#  4.58,
#  6.14,
#  3.65,
#  3.1,
#  2.31,
#  4.44,
#  4.17,
#  28.28,
#  4.82,
#  23.56,
#  2.57,
#  2.06,
#  12.23,
#  12.77,
#  10.68,
#  17.21,
#  9.13,
#  4.19,
#  4.21,
#  4.79,
#  4.52,
#  2.84,
#  5.65,
#  4.45,
#  3.93,
#  1.96,
#  3.21,
#  2.36,
#  3.74,
#  2.0,
#  2.89,
#  3.84,
#  4.29,
#  2.08,
#  5.48,
#  2.83,
#  15.98,
#  2.03,
#  5.28,
#  5.01,
#  6.96,
#  2.58,
#  7.52,
#  15.9,
#  20.81,
#  26.99,
#  2.86,
#  7.24,
# ...

# %%
len(outlier)
# Out:
# 401

# %%
ind1=aq_df['CO']>up_limit 
coi=aq_df.loc[ind1].index
coi
# Out:
# Int64Index([   2,    3,    7,   10,   14,   15,   16,   17,   18,   19,
#             ...
#             5266, 5267, 5341, 5402, 5447, 5448, 5449, 5492, 5493, 5558],
#            dtype='int64', length=401)

# %%
aq_df.drop(coi,inplace=True,axis=0)

# %%
aq_df.shape
# Out:
# (3536, 12)

# %%
Q1=np.percentile(aq_df['SO2'],25,interpolation='midpoint')
Q2=np.percentile(aq_df['SO2'],50,interpolation='midpoint')
Q3=np.percentile(aq_df['SO2'],75,interpolation='midpoint')
IQR=Q3-Q1
low_lim=Q1-1.5*IQR
up_limit=Q3+1.5*IQR
print(up_limit)
print(low_lim)
outlier=[]
for x in aq_df['SO2']:
    if(x>up_limit)or(x<low_lim):
        outlier.append(x)
outlier
# Out:
# 11.8525
# -0.6075000000000008
# [12.84,
#  12.98,
#  13.39,
#  29.11,
#  26.42,
#  15.91,
#  18.89,
#  15.06,
#  15.38,
#  48.23,
#  27.96,
#  16.6,
#  17.36,
#  21.92,
#  13.18,
#  12.45,
#  14.35,
#  13.46,
#  14.55,
#  13.92,
#  14.62,
#  16.07,
#  16.03,
#  22.46,
#  19.41,
#  12.69,
#  12.13,
#  12.74,
#  11.88,
#  13.1,
#  12.76,
#  15.0,
#  14.04,
#  12.82,
#  13.4,
#  14.34,
#  11.86,
#  13.06,
#  14.31,
#  14.9,
#  14.02,
#  15.72,
#  12.8,
#  14.18,
#  12.68,
#  12.36,
#  12.1,
#  12.19,
#  11.9,
#  12.36,
#  12.7,
#  14.96,
#  12.23,
#  12.86,
#  12.05,
#  13.31,
#  12.52,
#  13.63,
#  13.03,
#  16.0,
#  26.16,
#  13.26,
#  19.65,
#  19.95,
#  14.79,
#  14.81,
#  12.73,
#  16.84,
#  22.92,
#  14.17,
#  18.8,
#  25.33,
#  21.76,
#  50.51,
#  22.92,
#  19.68,
#  21.41,
#  16.78,
#  12.15,
#  14.28,
#  17.43,
#  12.98,
#  20.78,
#  30.67,
#  20.43,
#  20.65,
#  14.77,
#  13.19,
#  14.06,
#  13.07,
#  12.61,
#  13.98,
#  14.76,
#  12.8,
#  14.86,
#  17.2,
#  27.34,
#  24.43,
# ...

# %%
len(outlier)
# Out:
# 201

# %%
ind1=aq_df['SO2']>up_limit 
soi=aq_df.loc[ind1].index
soi
aq_df.drop(soi,inplace=True,axis=0)
aq_df.shape
# Out:
# (3335, 12)

# %%
Q1=np.percentile(aq_df['O3'],25,interpolation='midpoint')
Q2=np.percentile(aq_df['O3'],50,interpolation='midpoint')
Q3=np.percentile(aq_df['O3'],75,interpolation='midpoint')
IQR=Q3-Q1
low_lim=Q1-1.5*IQR
up_limit=Q3+1.5*IQR
print(up_limit)
print(low_lim)
outlier=[]
for x in aq_df['O3']:
    if(x>up_limit)or(x<low_lim):
        outlier.append(x)
outlier
# Out:
# 70.20499999999998
# -10.034999999999993
# [76.36,
#  81.34,
#  109.66,
#  74.38,
#  95.21,
#  70.86,
#  83.69,
#  91.3,
#  81.46,
#  73.5,
#  90.99,
#  82.31,
#  92.04,
#  72.89,
#  82.71,
#  81.71,
#  72.36,
#  74.87,
#  71.02,
#  74.0,
#  79.9,
#  70.67,
#  73.43,
#  71.42,
#  77.45,
#  71.51,
#  74.93,
#  71.42,
#  91.71,
#  86.53,
#  71.97,
#  71.82,
#  71.49,
#  71.74,
#  74.11,
#  97.28]

# %%
len(outlier)
# Out:
# 36

# %%
ind1=aq_df['O3']>up_limit 
oi=aq_df.loc[ind1].index
oi
aq_df.drop(oi,inplace=True,axis=0)
aq_df.shape
# Out:
# (3299, 12)

# %% [markdown]
# handled outliers in all columns

# %%
#aq_df=pd.get_dummies(aq_df)
#aq_df

# %%
aq_df.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'AQI'],
#       dtype='object')

# %% [markdown]
# # label encoding city

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
aq_df['City']=le.fit_transform(aq_df['City'])

# %%
aq_df.shape
# Out:
# (3299, 12)

# %%
aq_df
# Out:
#       City        Date  PM2.5    PM10    NO    NO2    NOx    NH3    CO   SO2  \
# 0        0  2015-01-01  33.99  58.245  3.26  17.33  10.88  20.36  0.33  3.54
# 1        0  2015-01-02  33.99  58.245  6.05  19.73  14.14  23.74  1.35  3.97
# 4        0  2015-01-05  33.99  58.245  9.52  22.17  21.76  31.38  1.83  4.71
# 5        0  2015-01-06  33.99  58.245  6.60  23.20  16.24  26.35  0.52  4.42
# 9        0  2015-01-10  33.99  58.245  3.38  29.23  16.76  34.17  1.69  3.08
# ...    ...         ...    ...     ...   ...    ...    ...    ...   ...   ...
# 5673     4  2020-06-27  18.06  36.040  8.19   9.50  12.46   6.57  0.61  8.38
# 5674     4  2020-06-28  22.51  43.970  7.00   7.38   9.57   6.09  0.61  8.32
# 5675     4  2020-06-29  23.17  46.710  8.87  10.75  12.88   5.65  0.68  8.07
# 5676     4  2020-06-30  20.66  41.530  8.65   9.93  12.41   5.88  0.53  8.40
# 5677     4  2020-07-01   2.00  35.000  1.68   2.30   2.58   5.62  0.42  6.15
#
#          O3   AQI
# 0     10.73  85.0
# ...

# %%
#aq_df.drop(['Date'],inplace=True,axis=1)

# %%
aq_df.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'AQI'],
#       dtype='object')

# %%
aq_df.shape
# Out:
# (3299, 12)

# %% [markdown]
# # min max scalling

# %%
#from sklearn import preprocessing
#min_max=preprocessing.MinMaxScaler(feature_range=(0,1))
#aq_df=min_max.fit_transform(aq_df)
#aq_df=pd.DataFrame(aq_df)

# %%
aq_df.shape
# Out:
# (3299, 12)

# %%
aq_df
# Out:
#       City        Date  PM2.5    PM10    NO    NO2    NOx    NH3    CO   SO2  \
# 0        0  2015-01-01  33.99  58.245  3.26  17.33  10.88  20.36  0.33  3.54
# 1        0  2015-01-02  33.99  58.245  6.05  19.73  14.14  23.74  1.35  3.97
# 4        0  2015-01-05  33.99  58.245  9.52  22.17  21.76  31.38  1.83  4.71
# 5        0  2015-01-06  33.99  58.245  6.60  23.20  16.24  26.35  0.52  4.42
# 9        0  2015-01-10  33.99  58.245  3.38  29.23  16.76  34.17  1.69  3.08
# ...    ...         ...    ...     ...   ...    ...    ...    ...   ...   ...
# 5673     4  2020-06-27  18.06  36.040  8.19   9.50  12.46   6.57  0.61  8.38
# 5674     4  2020-06-28  22.51  43.970  7.00   7.38   9.57   6.09  0.61  8.32
# 5675     4  2020-06-29  23.17  46.710  8.87  10.75  12.88   5.65  0.68  8.07
# 5676     4  2020-06-30  20.66  41.530  8.65   9.93  12.41   5.88  0.53  8.40
# 5677     4  2020-07-01   2.00  35.000  1.68   2.30   2.58   5.62  0.42  6.15
#
#          O3   AQI
# 0     10.73  85.0
# ...

# %%
aq_df.describe()
# Out:
#               City        PM2.5         PM10           NO          NO2  \
# count  3299.000000  3299.000000  3299.000000  3299.000000  3299.000000
# mean      1.688390    31.187851    52.996884     6.294077    15.762186
# std       1.621534    15.674424    16.719000     3.822219     8.609649
# min       0.000000     1.720000     0.210000     0.060000     0.060000
# 25%       0.000000    19.255000    41.760000     2.975000     9.080000
# 50%       1.000000    29.160000    58.245000     6.280000    14.770000
# 75%       4.000000    39.220000    58.245000     8.800000    21.515000
# max       4.000000    86.310000    92.770000    18.820000    40.310000
#
#                NOx          NH3           CO          SO2           O3  \
# count  3299.000000  3299.000000  3299.000000  3299.000000  3299.000000
# mean     14.405265    17.350133     0.832092     5.508509    30.706256
# std       9.036474    13.836712     0.402684     2.323485    14.092569
# ...

# %%
x = aq_df.drop(['AQI','Date'],axis=1)
y=aq_df['AQI']

# %%
from sklearn import preprocessing
min_max = preprocessing.MinMaxScaler(feature_range=(0,1))
x= min_max.fit_transform(x) #storing back to x
x=pd.DataFrame(x)

# %%
x.describe()
# Out:
#                  0            1            2            3            4  \
# count  3299.000000  3299.000000  3299.000000  3299.000000  3299.000000
# mean      0.422098     0.348361     0.570299     0.332307     0.390116
# std       0.405383     0.185299     0.180629     0.203743     0.213904
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.207294     0.448898     0.155384     0.224099
# 50%       0.250000     0.324388     0.626999     0.331557     0.365466
# 75%       1.000000     0.443315     0.626999     0.465885     0.533043
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                  5            6            7            8            9
# count  3299.000000  3299.000000  3299.000000  3299.000000  3299.000000
# mean      0.371270     0.260480     0.440260     0.446064     0.422138
# std       0.232899     0.207852     0.213060     0.203280     0.206303
# ...

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# 1.descriptive statistics

# %%
aq_df.describe()
# Out:
#               City        PM2.5         PM10           NO          NO2  \
# count  3299.000000  3299.000000  3299.000000  3299.000000  3299.000000
# mean      1.688390    31.187851    52.996884     6.294077    15.762186
# std       1.621534    15.674424    16.719000     3.822219     8.609649
# min       0.000000     1.720000     0.210000     0.060000     0.060000
# 25%       0.000000    19.255000    41.760000     2.975000     9.080000
# 50%       1.000000    29.160000    58.245000     6.280000    14.770000
# 75%       4.000000    39.220000    58.245000     8.800000    21.515000
# max       4.000000    86.310000    92.770000    18.820000    40.310000
#
#                NOx          NH3           CO          SO2           O3  \
# count  3299.000000  3299.000000  3299.000000  3299.000000  3299.000000
# mean     14.405265    17.350133     0.832092     5.508509    30.706256
# std       9.036474    13.836712     0.402684     2.323485    14.092569
# ...

# %% [markdown]
# value counts

# %%
#for i in['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3']:
 #   aq_df[i].value_counts()

# %%
aq_df['City'].value_counts()
# Out:
# 1    1043
# 0    1000
# 4     967
# 2     208
# 3      81
# Name: City, dtype: int64

# %%
aq_df['AQI'].value_counts()
# Out:
# 85.0     224
# 70.0      83
# 65.0      77
# 66.0      76
# 74.0      68
#         ...
# 187.0      1
# 195.0      1
# 196.0      1
# 199.0      1
# 189.0      1
# Name: AQI, Length: 178, dtype: int64

# %% [markdown]
# 3.boxplot a method for exploratory analysis

# %%
plt.boxplot(aq_df['NH3'])
plt.title('Box plot of NH3')
plt.show()

# %%
plt.boxplot(aq_df['PM2.5'])
plt.title('Box plot of PM2.5')
plt.show()

# %%
plt.boxplot(aq_df['PM10'])
plt.title('Box plot of PM10')
plt.show()

# %%
plt.boxplot(aq_df['CO'])
plt.title('Box plot of CO')
plt.show()

# %%
plt.boxplot(aq_df['NO'])
plt.title('Box plot of NO')
plt.show()

# %%
#fig,axes = plt.subplots(3,3, figsize=(40,50))
#sns.boxplot(x=aq_df['NO2'],y=aq_df['City'], hue=aq_df['AQI'])

# %% [markdown]
# 4.using group by

# %%
#aq_df.groupby(['City','AQI']).mean()

# %%
aq_df.isna().sum()
# Out:
# City     0
# Date     0
# PM2.5    0
# PM10     0
# NO       0
# NO2      0
# NOx      0
# NH3      0
# CO       0
# SO2      0
# O3       0
# AQI      0
# dtype: int64

# %%
columns = aq_df.columns
air_pollutants = aq_df[columns[2:11]]
air_pollutants.head(0)
# Out:
# Empty DataFrame
# Columns: [PM2.5, PM10, NO, NO2, NOx, NH3, CO, SO2, O3]
# Index: []

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.25)

# %%
#1.LINEAR REGRESSION

# %%
from sklearn import linear_model
lr1 = linear_model.LinearRegression()
model = lr1.fit(x_train,y_train)
y_pred = model.predict(x_test)

from sklearn.metrics import mean_squared_error        # to calculate efficiency of our model.
from sklearn.metrics import r2_score
print('MSE is :', mean_squared_error(y_test,y_pred))
print('R2 value:', r2_score(y_test,y_pred))
# Out:
# MSE is : 412.0617978729659
# R2 value: 0.5056693985558547

# %%
#2.DECISION TREE

# %%
from sklearn.tree import DecisionTreeRegressor

dt_model = DecisionTreeRegressor()
model=dt_model.fit(x_train, y_train)
y_pred = dt_model.predict(x_test)

from sklearn.metrics import mean_squared_error
print('MSE is :', mean_squared_error(y_test,y_pred))
from sklearn.metrics import r2_score
print('R2 value:', r2_score(y_test,y_pred))
# Out:
# MSE is : 602.5757706696596
# R2 value: 0.27711900334271533

# %%
#MODEL 3 SUPPORT VECTOR MACHINE

# %%
#by linear svm 
from sklearn.svm import SVC

svm_linear = SVC(kernel ='linear')
svm_linear.fit(x_train, y_train)
y_pred = svm_linear.predict(x_test)

from sklearn.metrics import mean_squared_error
print('MSE is :', mean_squared_error(y_test,y_pred))
from sklearn.metrics import r2_score
print('R2 value:', r2_score(y_test,y_pred))
# Out:
# MSE is : 858.0448484848484
# R2 value: -0.02935488853137702

# %%
#standardising features
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)
svm_linear = SVC(kernel='linear')
svm_linear.fit(x_train, y_train)
y_pred = svm_linear.predict(x_test)

from sklearn.metrics import mean_squared_error
print('MSE is :', mean_squared_error(y_test,y_pred))
from sklearn.metrics import r2_score
print('R2 value:', r2_score(y_test,y_pred))
# Out:
# MSE is : 576.88
# R2 value: 0.3079449761343489

# %%
svm_poly = SVC(kernel= 'poly', degree=3)
svm_poly.fit(x_train, y_train)
y_pred = svm_poly.predict(x_test)

from sklearn.metrics import mean_squared_error
print('MSE is :', mean_squared_error(y_test,y_pred))
from sklearn.metrics import r2_score
print('R2 value:', r2_score(y_test,y_pred))
# Out:
# MSE is : 569.1539393939394
# R2 value: 0.3172135572207355

# %%
svm_rad = SVC(kernel='rbf')
svm_rad.fit(x_train, y_train)
y_pred = svm_rad.predict(x_test)

from sklearn.metrics import mean_squared_error
print('MSE is :', mean_squared_error(y_test,y_pred))
from sklearn.metrics import r2_score
print('R2 value:', r2_score(y_test,y_pred))
# Out:
# MSE is : 668.5587878787878
# R2 value: 0.19796237016182683

# %%
from sklearn.ensemble import RandomForestRegressor

rf=RandomForestRegressor()
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)

from sklearn.metrics import mean_squared_error
print('MSE is :', mean_squared_error(y_test,y_pred))
from sklearn.metrics import r2_score
print('R2 value:', r2_score(y_test,y_pred))
# Out:
# MSE is : 345.3773082845612
# R2 value: 0.5856675542096687

# %%
from sklearn.ensemble import RandomForestRegressor

import xgboost as xgb
model=xgb.XGBRegressor()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
from sklearn.metrics import mean_squared_error
print('MSE is :', mean_squared_error(y_test,y_pred))
from sklearn.metrics import r2_score
print('R2 value:', r2_score(y_test,y_pred))
# Out:
# MSE is : 385.9603488814427
# R2 value: 0.5369820440016262

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]

# Number of features to consider at every split
max_features = ['auto', 'sqrt']

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]

# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]
# Method of selecting samples for training each tree
# bootstrap = [True, False]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
rf = RandomForestRegressor()
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 100, cv = 5, verbose=2)
rf_random.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=300; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=300; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=300; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=300; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=100, n_estimators=300; total time=   0.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=200; total time=   0.2s
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 1100,
#  'min_samples_split': 2,
#  'min_samples_leaf': 2,
#  'max_features': 'sqrt',
#  'max_depth': 25}

# %%
rf_random.best_score_
# Out:
# -263.99344856143307

# %%
y_pred=rf_random.predict(x_test)

# %%
sns.distplot(y_test-y_pred)
# Out:
# <AxesSubplot:xlabel='AQI', ylabel='Density'>

# %%
plt.scatter(y_test,y_pred)

# %%
from sklearn.metrics import mean_squared_error
print('MSE is :', mean_squared_error(y_test,y_pred))
from sklearn.metrics import r2_score
print('R2 value:', r2_score(y_test,y_pred))
# Out:
# MSE is : 328.1605730282974
# R2 value: 0.6063216384709746
