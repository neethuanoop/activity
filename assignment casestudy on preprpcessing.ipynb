# %% [markdown]
# 1.Load data to the python environment

# %%
import warnings
warnings.filterwarnings("ignore")#to ignore warnings

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#importing necessary libraries

# %%
#reading data
#data_tit=pd.read_csv("titanic_dataset.csv")

# %%
data_tit=pd.read_csv("titanic_dataset.csv",index_col='PassengerId')#making passengerId as index column

# %%
data_tit
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# # checking basic details of dataset

# %%
data_tit.shape
# Out:
# (891, 11)

# %%
data_tit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
data_tit.describe(include='all')
# Out:
#           Survived      Pclass                    Name   Sex         Age  \
# count   891.000000  891.000000                     891   891  714.000000
# unique         NaN         NaN                     891     2         NaN
# top            NaN         NaN  Alexander, Mr. William  male         NaN
# freq           NaN         NaN                       1   577         NaN
# mean      0.383838    2.308642                     NaN   NaN   29.699118
# std       0.486592    0.836071                     NaN   NaN   14.526497
# min       0.000000    1.000000                     NaN   NaN    0.420000
# 25%       0.000000    2.000000                     NaN   NaN   20.125000
# 50%       0.000000    3.000000                     NaN   NaN   28.000000
# 75%       1.000000    3.000000                     NaN   NaN   38.000000
# max       1.000000    3.000000                     NaN   NaN   80.000000
#
#              SibSp       Parch    Ticket        Fare        Cabin Embarked
# ...

# %%
data_tit.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
data_tit['Age']=data_tit['Age'].fillna(data_tit['Age'].median())

# %%
data_tit.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data_tit.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
data_tit.fillna(value={'Cabin':'unknown'},inplace=True)

# %%
data_tit
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data_tit.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    2
# dtype: int64

# %%
data_tit['Embarked'].fillna(data_tit['Embarked'].value_counts().index[0],inplace=True)

# %%
data_tit.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
#from  numpy import isnan
#from sklearn.impute import 
#=categoricalImputer()
#ata=np.array(data_tit['Embarked'],dtype=object)
#imputer.fit_transform(data)

# %%
data_tit['Cabin'].fillna(data_tit['Cabin'].value_counts().index[0],inplace=True)

# %%
data_tit
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data_tit.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
data_tit.shape
# Out:
# (891, 11)

# %%
#fregraph=data_tit=data_tit.select_dtypes(include=['float'])
#fregraph.hist(figsize=(20,15))
#plt.show()

# %% [markdown]
# handling outliters in ateleast 3 cloumns

# %%
Q1=np.percentile(data_tit['Age'],25,interpolation='midpoint')
Q2=np.percentile(data_tit['Age'],50,interpolation='midpoint')
Q3=np.percentile(data_tit['Age'],75,interpolation='midpoint')

# %%
print(Q1)
print(Q2)
print(Q3)
# Out:
# 22.0
# 28.0
# 35.0

# %%
IQR=Q3-Q1#IQr means interb quartile range

# %%
low_lim=Q1-1.5*IQR
up_limit=Q3+1.5*IQR

# %%
print(up_limit)
print(low_lim)
# Out:
# 54.5
# 2.5

# %%
#finding outliers
outlier=[]
for x in data_tit['Age']:
    if(x>up_limit)or(x<low_lim):
        outlier.append(x)

# %%
outlier#all outliers present in the dataset
# Out:
# [2.0,
#  58.0,
#  55.0,
#  2.0,
#  66.0,
#  65.0,
#  0.83,
#  59.0,
#  71.0,
#  70.5,
#  2.0,
#  55.5,
#  1.0,
#  61.0,
#  1.0,
#  56.0,
#  1.0,
#  58.0,
#  2.0,
#  59.0,
#  62.0,
#  58.0,
#  63.0,
#  65.0,
#  2.0,
#  0.92,
#  61.0,
#  2.0,
#  60.0,
#  1.0,
#  1.0,
#  64.0,
#  65.0,
#  56.0,
#  0.75,
#  2.0,
#  63.0,
#  58.0,
#  55.0,
#  71.0,
#  2.0,
#  64.0,
#  62.0,
#  62.0,
#  60.0,
#  61.0,
#  57.0,
#  80.0,
#  2.0,
#  0.75,
#  56.0,
#  58.0,
#  70.0,
#  60.0,
#  60.0,
#  70.0,
#  0.67,
#  57.0,
#  1.0,
#  0.42,
#  2.0,
#  1.0,
#  62.0,
#  0.83,
#  74.0,
#  56.0]

# %%
data_tit.shape
# Out:
# (891, 11)

# %%
ind1=data_tit['Age']>up_limit
ageindex=data_tit.loc[ind1].index

# %%
ageindex
# Out:
# Int64Index([ 12,  16,  34,  55,  95,  97, 117, 153, 171, 175, 196, 233, 253,
#             269, 276, 281, 327, 367, 439, 457, 468, 484, 488, 493, 494, 546,
#             556, 571, 588, 626, 627, 631, 648, 660, 673, 685, 695, 746, 773,
#             830, 852, 880],
#            dtype='int64', name='PassengerId')

# %%
data_tit.drop(ageindex,inplace=True)

# %%
data_tit.shape
# Out:
# (849, 11)

# %%
ind2=data_tit['Age']<low_lim
ageindex1=data_tit.loc[ind2].index

# %%
data_tit.drop(ageindex1,inplace=True)

# %%
data_tit.shape
# Out:
# (825, 11)

# %%
Q1=np.percentile(data_tit['Fare'],25,interpolation='midpoint')
Q2=np.percentile(data_tit['Fare'],50,interpolation='midpoint')
Q3=np.percentile(data_tit['Fare'],75,interpolation='midpoint')

# %%
print(Q1)
print(Q2)
print(Q3)
# Out:
# 7.8958
# 13.4167
# 30.0708

# %%
IQR=Q3-Q1

# %%
low_lim=Q1-1.5*IQR
up_limit=Q3+1.5*IQR

# %%
print(up_limit)
print(low_lim)
# Out:
# 63.333299999999994
# -25.366699999999994

# %%
outlier=[]
for x in data_tit['Fare']:
    if(x>up_limit)or(x<low_lim):
        outlier.append(x)

# %%
outlier
# Out:
# [71.2833,
#  263.0,
#  146.5208,
#  82.1708,
#  76.7292,
#  80.0,
#  83.475,
#  73.5,
#  263.0,
#  63.3583,
#  77.2875,
#  247.5208,
#  73.5,
#  77.2875,
#  79.2,
#  66.6,
#  69.55,
#  69.55,
#  69.55,
#  113.275,
#  76.2917,
#  90.0,
#  83.475,
#  90.0,
#  79.2,
#  86.5,
#  512.3292,
#  79.65,
#  135.6333,
#  78.85,
#  91.0792,
#  247.5208,
#  110.8833,
#  108.9,
#  83.1583,
#  262.375,
#  164.8667,
#  134.5,
#  69.55,
#  135.6333,
#  153.4625,
#  133.65,
#  66.6,
#  134.5,
#  263.0,
#  69.3,
#  135.6333,
#  82.1708,
#  211.5,
#  227.525,
#  73.5,
#  120.0,
#  113.275,
#  90.0,
#  120.0,
#  81.8583,
#  89.1042,
#  91.0792,
#  90.0,
#  78.2667,
#  151.55,
#  86.5,
#  108.9,
#  93.5,
#  221.7792,
#  106.425,
#  71.0,
#  106.425,
#  110.8833,
#  227.525,
#  79.65,
#  110.8833,
#  79.65,
#  78.2667,
#  153.4625,
#  65.0,
#  77.9583,
#  69.3,
#  76.7292,
#  73.5,
#  133.65,
#  73.5,
#  512.3292,
#  76.7292,
#  211.3375,
#  110.8833,
#  227.525,
#  151.55,
#  227.525,
#  211.3375,
# ...

# %%
ind1=data_tit['Fare']>up_limit
fareindex=data_tit.loc[ind1].index

# %%
data_tit.drop(fareindex,inplace=True)

# %%
data_tit.shape
# Out:
# (718, 11)

# %%
Q1=np.percentile(data_tit['SibSp'],25,interpolation='midpoint')
Q2=np.percentile(data_tit['SibSp'],50,interpolation='midpoint')
Q3=np.percentile(data_tit['SibSp'],75,interpolation='midpoint')

# %%
print(Q1)
print(Q2)
print(Q3)
# Out:
# 0.0
# 0.0
# 1.0

# %%
IQR=Q3-Q1#IQr means interb quartile range

# %%
low_lim=Q1-1.5*IQR
up_limit=Q3+1.5*IQR

# %%
print(up_limit)
print(low_lim)
# Out:
# 2.5
# -1.5

# %%
outlier=[]
for x in data_tit['SibSp']:
    if(x>up_limit)or(x<low_lim):
        outlier.append(x)

# %%
outlier
# Out:
# [3,
#  4,
#  5,
#  3,
#  4,
#  5,
#  3,
#  4,
#  3,
#  4,
#  3,
#  4,
#  4,
#  4,
#  4,
#  3,
#  3,
#  5,
#  3,
#  4,
#  4,
#  3,
#  5,
#  4,
#  3,
#  4,
#  4,
#  3,
#  4]

# %%
ind1=data_tit['SibSp']>up_limit
sibspindex=data_tit.loc[ind1].index

# %%
data_tit.drop(sibspindex,inplace=True)

# %%
data_tit.shape
# Out:
# (689, 11)

# %%
df=data_tit.drop(['Survived','Name'],axis=1)
df
# Out:
#              Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# PassengerId
# 1                 3    male  22.0      1      0         A/5 21171   7.2500
# 3                 3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 4                 1  female  35.0      1      0            113803  53.1000
# 5                 3    male  35.0      0      0            373450   8.0500
# 6                 3    male  28.0      0      0            330877   8.4583
# ...             ...     ...   ...    ...    ...               ...      ...
# 887               2    male  27.0      0      0            211536  13.0000
# 888               1  female  19.0      0      0            112053  30.0000
# 889               3  female  28.0      1      2        W./C. 6607  23.4500
# 890               1    male  26.0      0      0            111369  30.0000
# 891               3    male  32.0      0      0            370376   7.7500
#
#                Cabin Embarked
# PassengerId
# ...

# %%
df=pd.get_dummies(df)
df
# Out:
#              Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# PassengerId
# 1                 3  22.0      1      0   7.2500           0         1
# 3                 3  26.0      0      0   7.9250           1         0
# 4                 1  35.0      1      0  53.1000           1         0
# 5                 3  35.0      0      0   8.0500           0         1
# 6                 3  28.0      0      0   8.4583           0         1
# ...             ...   ...    ...    ...      ...         ...       ...
# 887               2  27.0      0      0  13.0000           0         1
# 888               1  19.0      0      0  30.0000           1         0
# 889               3  28.0      1      2  23.4500           1         0
# 890               1  26.0      0      0  30.0000           0         1
# 891               3  32.0      0      0   7.7500           0         1
#
#              Ticket_110465  Ticket_110564  Ticket_111320  ...  Cabin_F2  \
# ...

# %%
import sklearn
from sklearn import preprocessing
min_max=preprocessing.MinMaxScaler(feature_range=(0,1))
df=min_max.fit_transform(df)
df=pd.DataFrame(df)

# %%
df.describe()
# Out:
#               0           1          2           3           4           5    \
# count  689.000000  689.000000  689.00000  689.000000  689.000000  689.000000
# mean     0.746734    0.504141    0.13643    0.044993    0.270959    0.312046
# std      0.361793    0.187161    0.25051    0.125771    0.213306    0.463665
# min      0.000000    0.000000    0.00000    0.000000    0.000000    0.000000
# 25%      0.500000    0.392157    0.00000    0.000000    0.127962    0.000000
# 50%      1.000000    0.490196    0.00000    0.000000    0.171068    0.000000
# 75%      1.000000    0.588235    0.00000    0.000000    0.382051    1.000000
# max      1.000000    1.000000    1.00000    1.000000    1.000000    1.000000
#
#               6           7           8           9    ...         670  \
# count  689.000000  689.000000  689.000000  689.000000  ...  689.000000
# mean     0.687954    0.002903    0.001451    0.001451  ...    0.002903
# ...
